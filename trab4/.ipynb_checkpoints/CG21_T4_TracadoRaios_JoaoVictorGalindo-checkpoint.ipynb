# %% [markdown]
# <h1>T4 - Traçado de Raios<h3/>
#
# <p></p>

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sin, cos, sqrt
import sys

TOL = sys.float_info.epsilon
print(TOL)
# Out:
# 2.220446049250313e-16

# %%
def vetor(x, y, z):
    return  np.array([x, y, z], dtype = np.float)

def dot(u, v):
    return (u[0] * v[0] + u[1] * v[1] + u[2] * v[2])

def norma(u):
    return sqrt(dot(u, u))

def unitario(v):
    s = norma(v)
    
    if (s > TOL):
        return v/s
    
    else:
        return None

def ang(v1, v2):
    num = dot(v1, v2)
    den = norm(v1) * norm(v2)
    
    return np.arccos(num/den) * 180 / np.pi if den > TOL else 0

def reflete(v, n):
    r = 2 * dot(v, n) * n - v
    return r

def cross(u, v):
    return vetor(u[1] * v[2] - u[2] * v[1], u[2] * v[0] - u[0] * v[2], u[0] * v[1] - u[1] * v[0])

# %%
class Camera:
    def __init__(self, fov, w, h, dfocal, eye, at, up):
        self.fov = fov
        self.w = w
        self.h = h
        self.dfocal = dfocal
        
        self.a = 2 * dfocal * np.tan(fov * np.pi / 360)
        self.b = self.a * w / h
        self.eye = eye
        
        self.ze = unitario(at - eye)
        self.xe = unitario(cross(self.ze, up))
        self.ye = cross(self.ze, self.xe)
        self.img = np.full((h, w, 3), 0.1, dtype = np.float64)
    
    def ray_to(self, x_im, y_im):
        dx = self.b * (x_im / self.w - 0.5)
        dy = self.a * (y_im / self.h - 0.5)
        dz = self.dfocal
        
        ray = dx * self.xe + dy * self.ye + dz * self.ze
        
        return ray
    
    def get_eye(self):
        return self.eye

    def pixel (self, x_im, y_im, rgb):
        self.img[y_im, x_im, :] = rgb
    
    def get_pixel(self, x, y):
        return self.img[y, x, :]
    
    def set_pixel(self, x, y, rgb):
        self.img[y, x, :] = rgb
        
    def get_w(self):
        return self.w
    
    def get_h(self):
        return self.h
    
    def imshow(self):
        self.img[self.img < 0] = 0
        self.img[self.img > 1] = 1
        
        plt.figure(figsize = (8, 8))
        plt.imshow(self.img)
        plt.show()
    
    def show(self):
        print("CAMERA:")
        print("fov =", self.fov, "d =", self.dfocal)
        print("(w, h) = (", self.w, ",", self.h, ")")
        print("(b, a) = (", self.b, ",", self.a, ")")
        print("xe =", self.xe)
        print("ye =", self.ye)
        print("ze =", self.ze)
        print("\n")

# %%
class Poligono:
    def __init__(self, pp, pn, material):
        self.pp = pp
        self.pn = pn
        self.ni = None
        self.material = material
        self.hitface = None
        pmin = np.amin(pp, 0)
        pmax = np.amax(pp, 0)
        self.size = np.amax(pmax - pmin)
    
    def show(self):
        print("POLIGONO:")
        for i in range(len(self.pp)):
            print(f'Plano {i}: ponto = {self.pp[i]}, normal = {self.pn[i]}')
        
        self.material.show()
        print("\n")
    
    def intercepta(self, origem, direcao):
        te = 0
        ts = np.inf
        obji = None
        
        for i in range(len(self.pp)):
            pn = self.pn[i]
            pp = self.pp[i]
            num = dot(pp - origem, pn)
            den = dot(direcao, pn)
            
            if den < -TOL:
                t = num / den
                
                if t > te:
                    te = t
                    obji = self
                    self.ni = pn
                    self.hitface = i
                
            elif den > TOL:
                t = num / den
                ts = t if t < ts else ts
                obji = self
            
            if ts < te:
                te = np.inf
                obji = None
                self.hitface = None
                break
        
        return te, obji
    
    def get_mat(self):
        return self.material
    
    def normal(self, ponto):
        return self.ni
    
    def get_texture(self, ponto):
        axis = [[1,2],[2,0],[0,1],[1,2],[2,0],[0,1]]
        i = axis[self.hitface][0]
        j = axis[self.hitface][1]
        u = abs(ponto[i] - self.pp[self.hitface][i]) / self.size
        v = abs(ponto[j] - self.pp[self.hitface][j]) / self.size
        return u, v

# %%
class Caixa(Poligono):
    def __init__(self, pmin, pmax, material):
        super().__init__([pmin, pmin, pmin, pmax, pmax, pmax], 
                         [vetor(-1, 0 , 0), vetor(0, -1, 0), vetor(0, 0, -1), 
                          vetor(1, 0 , 0), vetor(0, 1, 0), vetor(0, 0, 1)], material)

# %%
class Esfera:
    def __init__(self, raio, centro, material):
        self.raio = raio
        self.centro = centro
        self.material = material
        
    def show(self):
        print("ESFERA:")
        print(f'raio = {self.raio}')
        print(f'centro = {self.centro}')
        self.material.show()
        print("\n")
    
    def intercepta(self, origem, direcao):
        a = dot(direcao, direcao)
        b = 2 * dot(direcao, origem - self.centro)
        c = dot(origem - self.centro, origem - self.centro) - self.raio**2
        delta = b**2 - 4 * a * c
        
        if delta > TOL:
            raiz = sqrt(delta)
            t1 = (-b - raiz) / (2 * a)
            t2 = (-b + raiz) / (2 * a)
            t = t1 if t1 < t2 else t2
            
            if t > 0:
                return t, self
            else:
                return np.inf, None
        else:
            return np.inf, None
     
    def normal(self, ponto):
        return unitario(ponto - self.centro)
    
    def get_mat(self):
        return self.material
    
    def get_texture(self, ponto):
        p = ponto - self.centro
        phi = np.arctan2(p[1], p[0])
        theta = np.arctan2(sqrt(p[0] ** 2 + p[1] ** 2), p[2])
        u = 0.5 * (1 + phi / np.pi)
        v = theta / np.pi
        return u, v

# %%
class Material:
    def __init__(self, kd, ks, ns, espelhamento, opacidade, textura):
        self.kd = kd
        self.ks = ks
        self.ns = ns
        self.espelhamento = espelhamento
        self.opacidade = opacidade
        if textura:
            img = plt.imread(textura)
            img = img / np.amax(img)
            img = img[:, :, :3]
            self.textura = img
        else:
            self.textura = None
        
    def show(self):
        print("MATERIAL:")
        print("Cor Difusa = ", self.kd)
        print("Cor Especular = ", self.ks)
        print("Coeficiente Especular = ", self.ns)
        print("Espelhamento = ", self.espelhamento)
        print("Opacidade = ", self.opacidade)
        print("\n")
    
    def get_phong(self, u, v):
        if self.textura is None:
            return self.kd, self.ks, self.ns
        else:
            u = u - int(u)
            v = v - int(v)
            ht, wt = self.textura.shape[:2]
            x = int(u * wt)
            y = int(v * ht)
            kd = self.textura[y, x, :]
            return kd, self.ks, self.ns
    
    def get_espelhamento(self):
        return self.espelhamento
    
    def get_opacidade(self):
        return self.opacidade

# %%
class Luz:
    def __init__(self, posicao, intensidade):
        self.posicao = posicao
        self.intensidade = intensidade
    
    def show(self):
        print("LUZ:")
        print(f'Posicao = {self.posicao}')
        print(f'Intensidade = {self.intensidade}')
        print("\n")
    
    def get_pos(self):
        return self.posicao
    
    def get_int(self):
        return self.intensidade

# %%
class Cena:
    def __init__(self, camera, objetos, luzes, ambiente):
        self.camera = camera
        self.objetos = objetos
        self.luzes = luzes
        self.ambiente = ambiente
    
    def show(self):
        print("CENA:")
        
        self.camera.show()
        
        for obj in self.objetos:
            obj.show()
        
        for luz in self.luzes:
            luz.show()
        
        print("Ambiente = ", self.ambiente)
        print("\n")
    
    def sombra(self,objeto, origem, direcao):
        ti = np.inf
        obji = None
                
        for obj in self.objetos:
            if obj is not objeto:
                t, objx = obj.intercepta(origem, direcao)
                
                if t > TOL and t < 1:
                    return True
        
        return False
    
    def shade(self, objeto, origem, ponto, nrec):
        u, v = objeto.get_texture(ponto)
        kd, ks, ns = objeto.get_mat().get_phong(u, v)
        cor = self.ambiente * kd
        material = objeto.get_mat()
        normal = objeto.normal(ponto)
        toEye = unitario(origem - ponto)
        
        for luz in self.luzes:
            toLuz = luz.get_pos() - ponto
            naSombra = self.sombra(objeto, ponto, toLuz)
            if naSombra is False:
                vluz = unitario(toLuz)
                cosseno1 = dot(vluz, normal)
            
                if cosseno1 > TOL:
                    # Difusa
                    cor += luz.get_int() * kd * cosseno1

                    # Especular
                    cosseno2 = dot(reflete(vluz, normal), toEye)

                    if cosseno2 > TOL:
                        cor += luz.get_int() * ks * (cosseno2 ** ns)

        # Recursão nos raios
        espelhamento = objeto.get_mat().get_espelhamento()
        if espelhamento > 0 and nrec < 5:
            dir_espelhada = reflete(toEye, normal)
            rgb_espelhado, obji = self.trace(objeto, ponto, dir_espelhada, nrec + 1)
            if obji:
                cor = (1 - espelhamento) * cor + espelhamento * rgb_espelhado
            else:
                cor = (1 - espelhamento) * cor
            
        return cor
    
    def trace(self, objeto, origem, direcao, nrec):
        ti = np.inf
        obji = None
                
        for obj in self.objetos:
            if obj is not objeto:
                t, objx = obj.intercepta(origem, direcao)
                if t < ti:
                    ti = t
                    obji = objx
                
        if obji and ti > TOL:
            ponto = origem + ti * direcao
            normal = obji.normal(ponto)
                    
            rgb = self.shade(obji, origem, ponto, nrec)
            return rgb, obji
            
        else:
            return None, None
    
    def render(self):
        w = self.camera.get_w()
        h = self.camera.get_h()
        origem = self.camera.get_eye()
        
        for y in range(h):           
            for x in range(w):
                direcao = self.camera.ray_to(x, y)
                rgb, obji = self.trace(None, origem, direcao, 0)
                
                if obji:
                    cor = self.camera.get_pixel(x, y)
                    self.camera.set_pixel(x, y, cor + rgb)

# %%
eye = vetor(100, 40, 40)
at = vetor(0, 0, 0)
up = vetor(0, 1, 0)
camera = Camera(90, 300, 300, 30, eye, at, up)
#camera.show()

# %%
luz1 = Luz(vetor(60, 120, 40), vetor(0.8, 0.8, 0.8))
luz2 = Luz(vetor(100, 40, 40), vetor(0.8, 0.8, 0.8))
#luz.show()

# %%
azul_metalico = Material(vetor(0, 0, 1), vetor(1, 1, 1), 30, 0, 1, "images\marmore.bmp")
amarelo_fosco = Material(vetor(0.7, 0.7, 0), vetor(0, 0, 0), 1, 0, 1, "images\mahogany.bmp")
amarelo_espelho = Material(vetor(0.7, 0.7, 0), vetor(0, 0, 0), 1, 1, 1, "images\mahogany.bmp")
#azul_metalico.show()
#amarelo_fosco.show()
#amarelo_espelho.show()

# %%
esfera = Esfera(25, vetor(0, 20, 0), azul_metalico)
#esfera.show()

# %%
piso = Caixa(vetor(-80, -50, -50), vetor(50, -45, 50), amarelo_fosco)
parede = Caixa(vetor(-80, -50, -60), vetor(50, 50, -50), amarelo_espelho)
#piso.show()
#parede.show()

# %%
objetos = [esfera, piso, parede]
materiais = [azul_metalico, amarelo_fosco, amarelo_espelho]
luzes = [luz1, luz2]
ambiente = vetor(0.1, 0.1, 0.1)
cena = Cena(camera, objetos, luzes, ambiente)
cena.show()
# Out:
# CENA:
# CAMERA:
# fov = 90 d = 30
# (w, h) = ( 300 , 300 )
# (b, a) = ( 59.999999999999986 , 59.99999999999999 )
# xe = [ 0.37139068  0.         -0.92847669]
# ye = [ 0.32325409 -0.93743687  0.12930164]
# ze = [-0.87038828 -0.34815531 -0.34815531]
#
#
# ESFERA:
# raio = 25
# centro = [ 0. 20.  0.]
# MATERIAL:
# Cor Difusa =  [0. 0. 1.]
# Cor Especular =  [1. 1. 1.]
# Coeficiente Especular =  30
# Espelhamento =  0
# Opacidade =  1
#
#
#
#
# POLIGONO:
# Plano 0: ponto = [-80. -50. -50.], normal = [-1.  0.  0.]
# Plano 1: ponto = [-80. -50. -50.], normal = [ 0. -1.  0.]
# Plano 2: ponto = [-80. -50. -50.], normal = [ 0.  0. -1.]
# Plano 3: ponto = [ 50. -45.  50.], normal = [1. 0. 0.]
# Plano 4: ponto = [ 50. -45.  50.], normal = [0. 1. 0.]
# Plano 5: ponto = [ 50. -45.  50.], normal = [0. 0. 1.]
# MATERIAL:
# Cor Difusa =  [0.7 0.7 0. ]
# Cor Especular =  [0. 0. 0.]
# Coeficiente Especular =  1
# Espelhamento =  0
# Opacidade =  1
#
#
#
#
# POLIGONO:
# Plano 0: ponto = [-80. -50. -60.], normal = [-1.  0.  0.]
# Plano 1: ponto = [-80. -50. -60.], normal = [ 0. -1.  0.]
# Plano 2: ponto = [-80. -50. -60.], normal = [ 0.  0. -1.]
# Plano 3: ponto = [ 50.  50. -50.], normal = [1. 0. 0.]
# Plano 4: ponto = [ 50.  50. -50.], normal = [0. 1. 0.]
# Plano 5: ponto = [ 50.  50. -50.], normal = [0. 0. 1.]
# MATERIAL:
# Cor Difusa =  [0.7 0.7 0. ]
# Cor Especular =  [0. 0. 0.]
# Coeficiente Especular =  1
# Espelhamento =  1
# Opacidade =  1
#
#
#
#
# LUZ:
# Posicao = [ 60. 120.  40.]
# Intensidade = [0.8 0.8 0.8]
#
#
# LUZ:
# Posicao = [100.  40.  40.]
# Intensidade = [0.8 0.8 0.8]
#
#
# Ambiente =  [0.1 0.1 0.1]

# %%
cena.render()

# %%
camera.imshow()
